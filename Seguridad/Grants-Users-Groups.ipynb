-- %% [markdown]
-- ##Grants

-- %%
--GRANT SELECT ON TABLE catalog_ut_smartdata.bronze.clientes TO `ahuaccachi28@gmail.com`;
GRANT SELECT ON TABLE catalog_dev.bronze.filmdetails TO `DEs`;
GRANT SELECT ON TABLE catalog_dev.bronze.movies TO `DEs`;
GRANT SELECT ON TABLE catalog_dev.bronze.posterpath TO `DEs`;

-- %%
GRANT USE CATALOG ON CATALOG catalog_dev TO `jorge.riv.rom.2025@outlook.com`;

-- %%
GRANT USE CATALOG ON CATALOG catalog_dev TO `DEs`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_dev.bronze TO `jorge.riv.rom.2025@outlook.com`;

GRANT USE SCHEMA ON SCHEMA catalog_dev.bronze TO `DEs`;
GRANT CREATE ON SCHEMA catalog_dev.bronze TO `DEs`;
GRANT CREATE ON SCHEMA catalog_dev.bronze TO `DMs`;
GRANT CREATE ON SCHEMA catalog_dev.bronze TO `CTs`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_dev.silver TO `DEs`;
GRANT CREATE ON SCHEMA catalog_dev.silver TO `DEs`;
GRANT CREATE ON SCHEMA catalog_dev.silver TO `DMs`;
GRANT CREATE ON SCHEMA catalog_dev.silver TO `CTs`;

-- %%
GRANT USE SCHEMA ON SCHEMA catalog_dev.golden TO `DEs`;
GRANT CREATE ON SCHEMA catalog_dev.golden TO `DEs`;
GRANT CREATE ON SCHEMA catalog_dev.golden TO `DMs`;
GRANT CREATE ON SCHEMA catalog_dev.golden TO `CTs`;

-- %%
GRANT CREATE TABLE ON SCHEMA catalog_dev.bronze TO `jorge.riv.rom.2025@outlook.com`;

-- %%
GRANT SELECT ON TABLE catalog_dev.bronze.filmdetails TO `DMs`;
GRANT SELECT ON TABLE catalog_dev.silver.movies_transformed TO `CTs`;
GRANT MODIFY ON TABLE catalog_dev.golden.golden_movies_partitioned TO `CTs`;

-- %%
SHOW GRANTS ON TABLE catalog_dev.silver.movies_transformed;

-- %%
SHOW GRANTS ON SCHEMA catalog_dev.bronze;

-- %%
SHOW GRANTS ON SCHEMA catalog_dev.silver;

-- %%
SHOW GRANTS ON SCHEMA catalog_dev.golden;

-- %%
SHOW GRANTS ON CATALOG catalog_dev;

-- %%
REVOKE USE CATALOG ON CATALOG catalog_dev FROM `DEs`;
--REVOKE USE CATALOG ON CATALOG catalog_dev FROM `jonathan_1635@hotmail.com`;

-- %%
REVOKE USE SCHEMA ON SCHEMA catalog_dev.bronze FROM `jonathan_1635@hotmail.com`;

-- %%
SHOW GRANTS ON SCHEMA catalog_dev.bronze;

-- %%
SHOW EXTERNAL LOCATIONS

-- %%
SHOW GRANTS ON EXTERNAL LOCATION `exlt-raw`

-- %%
GRANT READ FILES
ON EXTERNAL LOCATION `exlt-raw`
TO `DEs`;

-- %%
GRANT WRITE FILES
ON EXTERNAL LOCATION `exlt-raw`
TO `DEs`;

-- %%
GRANT ALL PRIVILEGES
ON EXTERNAL LOCATION `exlt-bronze`
TO `DEs`;

-- %%
DROP GROUP `DMs`;

-- %%
DROP GROUP `data_engineers`;

-- %%
CREATE GROUP  `data_engineers`;

-- %%
CREATE GROUP  `DMs`;

-- %%
ALTER GROUP `data_engineers`
ADD USER `jorge.riv.rom.2025@outlook.com`;

-- %%
SHOW USERS;
